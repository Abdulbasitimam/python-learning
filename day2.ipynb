# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulbasitimam/python-learning/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(True)
print(False)
a=2
b=22
b+=a
b-=a

print(b)
print("Addition :", a+b )
print("Subtraction :", a-b )
print("Multiplication :", a*b )
print("Division :", a/b )
print("Without reminder floor division :", a//b )
print ("Modulus: ", a%b )
print("Exponentiation : ", a**b)
# Out:
# True
# False
# 22
# Addition : 24
# Subtraction : -20
# Multiplication : 44
# Division : 0.09090909090909091
# Without reminder floor division : 0
# Modulus:  2
# Exponentiation :  4194304

# %%
print( input("Floating Number PI "))
print("Floaing Number Gravity", 9.81)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_595/4140151804.py in <cell line: 0>()
# ----> 1 print( input("Floating Number PI "))
#       2 print("Floaing Number Gravity", 9.81)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
# ...

# %%
#complex numbers start
print("This is complex number", (1+2j))
print((1+2j)**(2+3j))
print("Exponentiation of complex number is :", (1+2j)**(2+3j))
# Out:
# This is complex number (1+2j)
# (-0.01513267242272266-0.179867483913335j)
# Exponentiation of complex number is : (-0.01513267242272266-0.179867483913335j)

# %%
a=13
b=20
add=a+b
sub=a-b
mul=a*b
div=a/b
remin=a%b
f_div=a//b
exp= a**b
print("a+b :", add)
print("a-b :", sub)
print("a*b :", mul)
print("a/b :", div)
print("a%b :", remin)
print("a//b :", f_div)
print("a**b :", exp)
# Out:
# a+b : 33
# a-b : -7
# a*b : 260
# a/b : 0.65
# a%b : 13
# a//b : 0
# a**b : 19004963774880799438801

# %%
#area/circumference of circle
radius= float(input("Radius of circle is:"))
ar= 3.14 * radius**2
print("The area of given radius of circle is:" , ar)

circum= 2*3.14*radius
print("The circumference of given radius of circle is:" , circum)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_595/814091579.py in <cell line: 0>()
#       1 #area/circumference of circle
# ----> 2 radius= float(input("Radius of circle is:"))
#       3 ar= 3.14 * radius**2
#       4 print("The area of given radius of circle is:" , ar)
#       5
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
#area of rectangle
a= int(input("length bata bhi: "))
b= int(input("widht bhi bata: "))
are= a*b
print("area of rectangle is ", are)
# Out:
# widht bhi bata:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_595/1272823087.py in <cell line: 0>()
# ----> 1 b= int(input("widht bhi bata: "))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
#weight of an object
mass= float(input("Mass of object :"))
gravity= float(input("Gravity batao :"))
weigh= mass*gravity
print("Total weight of given mass after applying gravity :", weigh)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_595/1323075508.py in <cell line: 0>()
#       1 #weight of an object
# ----> 2 mass= float(input("Mass of p=object :"))
#       3 gravity= float(input("Gravity batao :"))
#       4 weigh= mass*gravity
#       5 print("Total weight of given mass after applying gravity :", weigh)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
#density of liquid
mass= 9
vol= 0.1
density= mass/vol
print(density)
# Out:
# 90.0

# %%
print(4>5)
print(4<5)
print(4==5)
print(4!=5)
print(4>=5)
print(4<=5)
print(4+5)
print(True==True)
print('a is a', 'a' is 'a')
print('abdul' in 'abdul bhai kee rola haii')
# Out:
# False
# True
# False
# True
# False
# True
# 9
# True
# a is a True
# True
# <>:9: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# <>:9: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# /tmp/ipykernel_595/2045531851.py:9: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   print('a is a', 'a' is 'a')

# %%
print (3>2 and 3<2)
print(3>2 or 3<2)
print(not(3>2 or 3<2))
print(not not not True)
# Out:
# False
# True
# False
# False

# %%
#exercises of end
age= 25
height= 5.7
comp_num= 1+3j

#rectangle thing
lenth= float(input("length of rectangle is:"))
height= float(input('height of rectangle is:'))
a= 0.5 * lenth * height
print(a)

#perimeter of triangle
a= input('enter side a: ')
b= input('enter side b: ')
c= input('enter side c: ')
peri= (a+b+c)
print(peri)
#area and perimeter of rectangle
l_rect= float(input('enter length of rectangle'))
w_rect= float(input('enter width of rectangle'))
ar_rect= (l_rect * w_rect)
print(ar_rect)
peri_rect= 2 * (l_rect + w_rect)
print(peri_rect)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_595/631928557.py in <cell line: 0>()
#       5
#       6 #rectangle thing
# ----> 7 lenth= float(input("length of rectangle is:"))
#       8 height= float(input('height of rectangle is:'))
#       9 a= 0.5 * lenth * height
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
#circle
rad= float(input('Radius likh bhi: '))
ar_circle= 3.14 * rad ** 2
print(ar_circle)
circum_circle= 2 * 3.14 * rad
print(circum_circle)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_595/3918715419.py in <cell line: 0>()
#       1 #circle
# ----> 2 rad= float(input('Radius likh bhi: '))
#       3 ar_circle= 3.14 * rad ** 2
#       4 print(ar_circle)
#       5 circum_circle= 2 * 3.14 * rad
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
#slope question

#y= mx+b so equation is y= 2x-2
m=2
b=-2
#finding y intercept, but x is 0 on y intercept so 2x will be 0
y_intercept= b

#finding x intercept, but y is 0 on x intercept so x=1
x_intercept= -b/m
# now print
print('Equation is: y= {m}x + ({b})' )
print('x-intercept is:', x_intercept )
print('y-intercept is:', y_intercept)
# Out:
# Equation is: y= {m}x + ({b})
# x-intercept is: 1.0
# y-intercept is: -2

# %%
#find slop and euclidean distance (2,2)(6,10) if we solve according to formula m= 10-2/6-2 which will be 2
x1,y1= 2,2
x2,y2= 6,10
m= x2-x1/y2-y1

print(m)

distance_nocorr= (x2-x1)**2 + (y2-y1)**2
print(distance_nocorr)
# Out:
# 3.8
# 80

# %%
m1=2
m2=3.8
if m1>m2:
  print("task 8 slop is higher")
elif m2>m1:
  print('task 9 slop is higher')
elif m2==m1:
  print('both are equal')
# Out:
# task 9 slop is higher

# %%
#Calculate the value of y (y = x^2 + 6x + 9). Try to use different x values and figure out at what x value y is going to be 0.
x=float(input('give value of x'))
y= x**2 + 6*x + 9
print(y)
while y==0:
  x=float(input('give value of x'))
y= x**2 + 2*x + 9
print(y)
# Out:
# give value of x2
# 17.0
# 17.0

# %%
for x in range(-5, 6):
    y = x**2 + 6*x + 9
    print(f"When x = {x}, y = {y}")

    if y == 0:
        print(f"--- Found it! y is 0 when x is {x} ---")
# Out:
# When x = -5, y = 4
# When x = -4, y = 1
# When x = -3, y = 0
# --- Found it! y is 0 when x is -3 ---
# When x = -2, y = 1
# When x = -1, y = 4
# When x = 0, y = 9
# When x = 1, y = 16
# When x = 2, y = 25
# When x = 3, y = 36
# When x = 4, y = 49
# When x = 5, y = 64

# %%
#Find the length of 'python' and 'dragon' and make a falsy comparison statement.
len_python= len('python')
len_dragon= len('draggon')
comparision= len_python == len_dragon
print('length of python:', len_python)
print('length of dragon: ', len_dragon )
print('comparision of length is: ', comparision)
# Out:
# length of python: 6
# length of dragon:  7
# comparision of length is:  False

# %%
#Use and operator to check if 'on' is found in both 'python' and 'dragon'
check_p= 'on' in 'python'
check_d= 'on' in 'dragon'
result= 'on' in 'python' and 'on' in 'dragon'
print(result)
result= False
print(result)
#I hope this course is not full of jargon. Use in operator to check if jargon is in the sentence.
check= 'jargon' in 'i hope this course is not full of jargon'
print(check)

len_python= len('python')
print(len_python)
len_python_tofloat= float(len_python)
print(len_python_tofloat)
len_python_tostring= str(len_python)
print(len_python_tostring)
# Out:
# True
# False
# True
# 6
# 6.0
# 6

# %%
#Even numbers are divisible by 2 and the remainder is zero. How do you check if a number is even or not using python?
lenth_python= len('python')
exp= lenth_python % 2
print(exp)
if exp == 0:
  exp= lenth_python // 2
  print('the number is even and multiple of ', exp)
# Out:
# 0
# the number is even and multiple of  3

# %%
#Check if the floor division of 7 by 3 is equal to the int converted value of 2.7.
f_div= 7//3
i= int(2.7)
print(f_div)
print(i)
result= f_div == i
print(result)
# Out:
# 2
# 2
# True

# %%
#Check if type of '10' is equal to type of 10
t1= type('10')
t2= type(10)
res= t1 == t2
print(res)

#Check if int('9.8') is equal to 10
i1= '9.8'
i2= 10
res= i1==i2
print(res)
# Out:
# False
# False

# %%
#Write a script that prompts the user to enter hours and rate per hour. Calculate pay of the person?

weekly_hr= float(input('What are your total hours of work each week'))
rate_prhr= float(input('what is your per hour rate'))
print('Your Weekly Pay is: ', weekly_hr * rate_prhr)
# Out:
# What are your total hours of work each week20
# what is your per hour rate20
# Your Weekly Pay is:  400.0

# %%
#Write a script that prompts the user to enter number of years. Calculate the number of seconds a person can live. Assume a person can live hundred years
years_ofperson= float(input('Enter number of Years you have lived in: '))
seconds_inyear= 60*60*24*365
person_lifeinsec= years_ofperson * seconds_inyear
print('Your whole life in seconds is ', person_lifeinsec)
# Out:
# Enter number of Years you have lived in: 20
# Your whole life in seconds is  630720000.0

# %%
#Write a Python script that displays the following table
for i in range(1,6):
  col1= i
  col2= 1
  col3= i
  col3= i**2
  col4= i**3
  col5= i**4
  print(col1, col2, col3, col4, col5 )
# Out:
# 1 1 1 1 1
# 2 1 4 8 16
# 3 1 9 27 81
# 4 1 16 64 256
# 5 1 25 125 625

# %%
print('i is i', i is i)
print(a  in 'analogy')

print(not True)
print(not not  not True)
print('True or False: ', True or False )
print('True and True: ', True and True)
print('4 is 2 ** 2:', 4 is 2 ** 2)
print(3 < 2 and 4 < 5 or 1>4)
# Out:
# i is i True
# False
# False
# False
# True or False:  True
# True and True:  True
# 4 is 2 ** 2: True
# False
# <>:8: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:8: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# /tmp/ipykernel_595/214694819.py:8: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print('4 is 2 ** 2:', 4 is 2 ** 2)

# %%
#string start
letter= 'Kee rolaa hai paa jee'
print(type(letter))
print(len(letter))
let= '''Hn jee
kia haal chaal
kiaa kr rhy hoo aaj kall'''
print(let)
space= ' '
full= letter + space + let
print(full)

print(len(full))
if len(letter) >= len(let):
  print("mazy kr kaka")
else: print('koi nii')
# Out:
# <class 'str'>
# 21
# Hn jee
# kia haal chaal
# kiaa kr rhy hoo aaj kall
# Kee rolaa hai paa jee Hn jee
# kia haal chaal
# kiaa kr rhy hoo aaj kall
# 68
# koi nii

# %%
print('hn \n jee kia haal \\ \t27 haiinnn\'\"')
# Out:
# hn
#  jee kia haal \ 	27 haiinnn'"

# %%
#stringss practice
print('I hope you are enjoying the python seriess')
print('Day \t\tTime \tClass')
print('Tuesday \t2:00 \tPhysics')
print('Monday \t\t3:00 \tChemistery')
print('Wednesday \t1:00 \tMaths')
print('Thursday \t6:00 \tScience')
print('Friday \t\t8:00 \tBiology')
print('Saturday \t9:00 \tSociology')
print('this is a \n backlash \\ dekhlo bhi agr ni dekhaa kabhii')
# Out:
# I hope you are enjoying the python seriess
# Day 		Time 	Class
# Tuesday 	2:00 	Physics
# Monday 		3:00 	Chemistery
# Wednesday 	1:00 	Maths
# Thursday 	6:00 	Science
# Friday 		8:00 	Biology
# Saturday 	9:00 	Sociology
# this is a
#  backlash \ dekhlo bhi agr ni dekhaa kabhii
