# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulbasitimam/python-learning/blob/main/day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
first_n= 'Abdul'
last_n= 'Basit'
age= 20
print('My first name is %s and my last name is %s and i am %d year old' %(first_n, last_n, age))

first_name = 'Asabeneh'
last_name = 'Yetayeh'
language = 'Python'
formated_string = 'I am %s %s. I teach %s' %(first_name, last_name, language)
print(formated_string)
# Out:
# My first name is Abdul and my last name is Basit and i am 20 year old
# I am Asabeneh Yetayeh. I teach Python

# %%
rad= int(input('give radius: '))
area= float(3.14* rad**2)
print('The given radius %d given by user, area of that radius circle is %f ' %(rad, area) )

py_lib= ['django', 'flask', 'matplot', 'numpy']
print('These are the libraries and frameworks of python %s' %(py_lib))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_547/1590259019.py in <cell line: 0>()
# ----> 1 rad= int(input('give radius: '))
#       2 area= float(3.14* rad**2)
#       3 print('The given radius %d given by user, area of that radius circle is %f ' %(rad, area) )
#       4
#       5 py_lib= ['django', 'flask', 'matplot', 'numpy']
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
f_name= 'abdul'
l_name= 'basit'
age= '20'
print('my first name is {} and my last name is {} while my age is {}' .format(f_name, l_name, age ))
a= 2
b= 5
print('{} + {} = {}' .format(a,b, a+b))
print('{} - {} = {}' .format(a,b, a-b))
print('{} * {} = {}' .format(a,b, a*b))
print('{} / {} = {}' .format(a,b, a/b))
print('{} % {} = {}' .format(a,b, a%b))
print('{} // {} = {}' .format(a,b, a//b))

# %%
redius= 10
pi= 3.14
area= pi * redius **2
print('the radius given is {} with the value of pi {} while the area after calculation is {}' .format(redius, pi, area))


a=10
b=20
print(f'{a} + {a} = {a+b}')
# Out:
# the radius given is 10 with the value of pi 3.14 while the area after calculation is 314.0
# 10 + 10 = 30

# %%
name= 'python'
a,b,c,d,e,f= name
print(a)
print(b)
print(c)
print(d)
print(e)
print(f)
# Out:
# p
# y
# t
# h
# o
# n

# %%
name= 'abdul'
f= name[0]
print(f)
f= name[-1]
print(f)
f= name[1]
print(f)
f= name[-2]
print(f)
# Out:
# a
# l
# b
# u

# %%
#slicing krty hain ab
name= 'abia'
f= name[0:1]
l= name[-1:-2]
print('from left {} and from right {}' .format(f,l))
print(f,l)

lan= 'language is fantastic'
left= lan[0:5]
right= lan[-1:]
print(left, right)
# Out:
# from left a and from right
# a
# langu c

# %%
#reversing string
h1='hello world'
print([::-1])
# Out:
#   File "/tmp/ipykernel_483/2974761207.py", line 3
#     print([::-1])
#            ^
# SyntaxError: invalid syntax

# %%
lan= 'language'
pto= lan[0:1:5]
print(pto)
print(lan.capitalize())
print(lan.count('a', 0,3))
print(lan.endswith('e'))
print(lan.endswith('g'))
# Out:
# l
# Language
# 1
# True
# False

# %%
#Concatenate the string 'Thirty', 'Days', 'Of', 'Python' to a single string, 'Thirty Days Of Python'.
st=['thirty', 'days', 'of', 'python']
ad= ' ' .join(st)
print(ad)
#Concatenate the string 'Coding', 'For' , 'All' to a single string, 'Coding For All'.
st1= ['coding', 'for', 'all']
rev= ' ' .join(st1)
print(rev)

#Declare a variable named company and assign it to an initial value "Coding For All".
company= 'Coding for all'
#Print the variable company using print().
print(company)
#Print the length of the company string using len() method and print().
print(len(company))
#Change all the characters to uppercase letters using upper() method.
print(company.upper())
#Change all the characters to lowercase letters using lower() method.
print(company.lower())
#Use capitalize(), title(), swapcase() methods to format the value of the string Coding For All.
print(company.capitalize())
print(company.swapcase())
print(company.title())
print(company.split())
# Out:
# thirty days of python
# coding for all
# Coding for all
# 14
# CODING FOR ALL
# coding for all
# Coding for all
# cODING FOR ALL
# Coding For All
# ['Coding', 'for', 'all']

# %%
#Make the following using string formatting methods:
#8 + 6 = 14
#8 - 6 = 2
#8 * 6 = 48
#8 / 6 = 1.33
#8 % 6 = 2
#8 // 6 = 1
#8 ** 6 = 262144

a= '8'
b= '6'
print(f'{a} + {b} = {a+b}')
print(f'{int(a)} - {int(b)} = {int(a-b)}')
print(f'{a} * {b} = {a*b}')
print(f'{a} / {b} = {a/b}')
print(f'{a} % {b} = {a%b}')
print(f'{a} // {b} = {a//b}')
print(f'{a} ** {b} = {a**b}')
# Out:
# 8 + 6 = 86
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_483/1927597709.py in <cell line: 0>()
#      11 b= '6'
#      12 print(f'{a} + {b} = {a+b}')
# ---> 13 print(f'{int(a)} - {int(b)} = {int(a-b)}')
#      14 print(f'{a} * {b} = {a*b}')
#      15 print(f'{a} / {b} = {a/b}')
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
