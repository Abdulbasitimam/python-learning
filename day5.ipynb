# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulbasitimam/python-learning/blob/main/day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
emp_tuple= ('emp ni', 'emp hai', 'emp ni bhi smj')
print(emp_tuple)
print(len(emp_tuple))

first, second, *rest= ('emp ni', 'emp hai', 'emp ni bhi smj')
print(first)
first= emp_tuple[0:2]
print(first)
# Out:
# ('emp ni', 'emp hai', 'emp ni bhi smj')
# 3
# emp ni
# ('emp ni', 'emp hai')

# %%
fruits = ('banana', 'orange', 'mango', 'lemon')
all= fruits[0:]
print(all)
last= len(fruits) - 1
print(fruits[last])
# Out:
# ('banana', 'orange', 'mango', 'lemon')
# lemon

# %%
fruits = ('banana', 'orange', 'mango', 'lemon')
fruits_lst= list(fruits)
print(fruits)
fruits_lst.append('banana')
print(fruits_lst)
last= fruits_lst + fruits_lst
print(last)
print('banana' in last)
print('kela' in last)
del last
last = ''
if last == '':
  print(f'Last delete hogya: {last}')
else:
  print('last abhi zinda hai')
# Out:
# ('banana', 'orange', 'mango', 'lemon')
# ['banana', 'orange', 'mango', 'lemon', 'banana']
# ['banana', 'orange', 'mango', 'lemon', 'banana', 'banana', 'orange', 'mango', 'lemon', 'banana']
# True
# False
# Last delete hogya:

# %%
#exercise
tpl = ()
bro= ('pehla bro', 'dosra bro')
sis= ('pehli sis', 'dosri sis')
tpl_sibs= bro + sis
print(tpl_sibs)
print(f'lenghts of sibs are: {len(tpl_sibs)}')
tpl_sibs= list(tpl_sibs)
if 'father' in tpl_sibs == True:
  tpl_sibs.append('father')
elif 'mother' in tpl_sibs == True:
  tpl_sibs.append('mother')
else:
  print("Parents are added already")
family= tpl_sibs
print(family)
# Out:
# ('pehla bro', 'dosra bro', 'pehli sis', 'dosri sis')
# lenghts of sibs are: 4
# Parents are added already
# ['pehla bro', 'dosra bro', 'pehli sis', 'dosri sis']
