# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulbasitimam/python-learning/blob/main/day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
st= set()
st= {'item1', 'item2', 'item3', 'item4', 'item5'}
fruits= {'banana', 'orange', 'apple', 'mango', 'strawberry'}
len_fruits= len(fruits)
print(fruits)
print(len_fruits)

print('item' in st)
print('mango' in fruits)

st.add('item6')
print(st)
st.add('item')
print(st)
fruits.update(['guava', 'kiwi', 'watermallon'])
print(fruits)
fruits.remove('guava')
print(fruits)
remove_fruit= fruits.pop()
print(remove_fruit)
st.clear()
print(st)
del st
st= 0
print(st)
lst= ['mera', 'naam', 'billu', 'kaalia', 'haii']
lst= set(lst)
print(lst)
st3= fruits.union(lst)
print(st3)
fuis= {'pehla fruit', 'dosra fruit', 'pehli'}
vege= {'pehli vege', 'dosri vege', 'pehli'}
vege.update(fuis)
print(vege)
fuis.intersection(vege)
print(fuis)
# Out:
# {'strawberry', 'orange', 'banana', 'apple', 'mango'}
# 5
# False
# True
# {'item5', 'item1', 'item4', 'item6', 'item3', 'item2'}
# {'item5', 'item1', 'item4', 'item6', 'item3', 'item', 'item2'}
# {'strawberry', 'watermallon', 'guava', 'orange', 'banana', 'kiwi', 'apple', 'mango'}
# {'strawberry', 'watermallon', 'orange', 'banana', 'kiwi', 'apple', 'mango'}
# strawberry
# set()
# 0
# {'billu', 'kaalia', 'naam', 'haii', 'mera'}
# {'billu', 'orange', 'kiwi', 'mera', 'kaalia', 'naam', 'watermallon', 'banana', 'haii', 'apple', 'mango'}
# {'dosra fruit', 'dosri vege', 'pehla fruit', 'pehli vege', 'pehli'}
# {'dosra fruit', 'pehli', 'pehla fruit'}

# %%
python = {'p', 'y', 't', 'h', 'o','n'}
dragon = {'d', 'r', 'a', 'g', 'o','n'}
python.intersection(dragon)
st1= {'item5', 'item1', 'item4'}
st2= {'item3', 'item1', 'item4'}
hn= st1.issubset(st2)
hnn= st1.issuperset(st2)
print(st1)
print(st2)
print(hn)
print(hnn)
h1= st1.difference(st2)
h2= st2.difference(st1)
print(h1)
print(h2)
print(st1.symmetric_difference(st2))
print(st2.symmetric_difference(st1))
print(st2.isdisjoint(st1))
print(st1.isdisjoint(st2))
# Out:
# {'item5', 'item4', 'item1'}
# {'item1', 'item4', 'item3'}
# False
# False
# {'item5'}
# {'item3'}
# {'item3', 'item5'}
# {'item5', 'item3'}
# False
# False

# %%
# sets exercise
it_companies = {'Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon'}
A = {19, 22, 24, 20, 25, 26}
B = {19, 22, 20, 25, 26, 24, 28, 27}
age = [22, 19, 24, 25, 26, 24, 25, 24]

print(len(it_companies))
it_companies.add('twitter')
it_companies.update(['lango', 'mango', 'bango'])
print(it_companies)
it_companies.remove('bango')
print(it_companies)

print(A.union(B))
# Out:
# 7
# {'Oracle', 'bango', 'Amazon', 'Google', 'Apple', 'mango', 'IBM', 'Facebook', 'Microsoft', 'lango', 'twitter'}
# {'Oracle', 'Amazon', 'Google', 'Apple', 'mango', 'IBM', 'Facebook', 'Microsoft', 'lango', 'twitter'}
# {19, 20, 22, 24, 25, 26, 27, 28}
