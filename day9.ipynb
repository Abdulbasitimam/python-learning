# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulbasitimam/python-learning/blob/main/day9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#functions started
def full_name():
  first_name= 'abdul'
  last_name= 'basit'
  space= ' '
  full_name= first_name + space + last_name
  print(full_name)
full_name()

def adding():
  first_num= 2
  sec_num= 3
  total= first_num + sec_num
  return total
adding()
# Out:
# abdul basit
# 5

# %%
def subtract_nums():
  first= int(input())
  sec= int(input())
  diff= sec - first
  return print('the difference between numbers are: ', diff)
subtract_nums()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_12092/245326120.py in <cell line: 0>()
#       4   diff= sec - first
#       5   return print('the difference between numbers are: ', diff)
# ----> 6 subtract_nums()
#
# /tmp/ipykernel_12092/245326120.py in subtract_nums()
#       1 def subtract_nums():
# ----> 2   first= int(input())
#       3   sec= int(input())
#       4   diff= sec - first
#       5   return print('the difference between numbers are: ', diff)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...

# %%
def greet(name):
  mesg= name + ', welcome to function'
  return mesg
greet('abdul')
print(greet('abdul, basit'))
# Out:
# abdul, basit, welcome to function

# %%
def table():
  num= int(input())
  for number in range(num):
    mul= number * number
    break
  return num
table()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_12092/3972336202.py in <cell line: 0>()
#       5     break
#       6   return num
# ----> 7 table()
#
# /tmp/ipykernel_12092/3972336202.py in table()
#       1 def table():
# ----> 2   num= int(input())
#       3   for number in range(num):
#       4     mul= number * number
#       5     break
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
print('Give radius')
r= int(input())
def area(r):
  area= 3.14 * r**2
  print(area)
def circum(r):
  circum= 2* 3.14 *r
  print(circum)
print("Press 1 for area and 2 for circumference")
num= int(input())
if num==1:
  area(r)

elif num==2:
  circum(r)
else:
  print('You give another number')
# Out:
# Give radius
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_12092/2368780798.py in <cell line: 0>()
#       1 print('Give radius')
# ----> 2 r= int(input())
#       3 def area(r):
#       4   area= 3.14 * r**2
#       5   print(area)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
# two arguments function
def add(first,sec):
  ad= first + sec
  return ad
add(2,3)
# Out:
# 5
