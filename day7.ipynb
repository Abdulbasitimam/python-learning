# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulbasitimam/python-learning/blob/main/day7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#dictionaries
dic= {'room1': 'member1',
      'room2': 'member2',
      'room3': 'member3',
      'room4': 'member4'}
print(dic)
bio_data= {
    'name': 'abd',
    'kaam': 'engineer',
    'age': 23,
    'work': 'analyst',
    'adress': {
        'street': 'abc street',
        'postal code': 123456
    },
    '#' : 1234577687868768767 ,
    'skills':['JavaScript', 'React', 'Node', 'MongoDB', 'Python']
}
print(bio_data)
length= len(bio_data)
print(length)
#accessing dict
print(bio_data['adress'])
print(bio_data['kaam'])
print(bio_data['skills'])
skills= bio_data.get('adress')
print(skills)
bio_data['married']= ['yes','no']
print(bio_data)
bio_data['adress']= 'abc street khulla market'
print(bio_data)
#checking
print('adress' in bio_data)
print('apna' in bio_data)

bio_data.popitem()
bio_data.pop('adress')
print(bio_data)
#changing to lists
print(bio_data.items())
dic.clear()
print(dic)
del dic
bio_2= bio_data.copy()
values=bio_2.values()
print(values)
# Out:
# {'room1': 'member1', 'room2': 'member2', 'room3': 'member3', 'room4': 'member4'}
# {'name': 'abd', 'kaam': 'engineer', 'age': 23, 'work': 'analyst', 'adress': {'street': 'abc street', 'postal code': 123456}, '#': 1234577687868768767, 'skills': ['JavaScript', 'React', 'Node', 'MongoDB', 'Python']}
# 7
# {'street': 'abc street', 'postal code': 123456}
# engineer
# ['JavaScript', 'React', 'Node', 'MongoDB', 'Python']
# {'street': 'abc street', 'postal code': 123456}
# {'name': 'abd', 'kaam': 'engineer', 'age': 23, 'work': 'analyst', 'adress': {'street': 'abc street', 'postal code': 123456}, '#': 1234577687868768767, 'skills': ['JavaScript', 'React', 'Node', 'MongoDB', 'Python'], 'married': ['yes', 'no']}
# {'name': 'abd', 'kaam': 'engineer', 'age': 23, 'work': 'analyst', 'adress': 'abc street khulla market', '#': 1234577687868768767, 'skills': ['JavaScript', 'React', 'Node', 'MongoDB', 'Python'], 'married': ['yes', 'no']}
# True
# False
# ...

# %%
#exercise name, color, breed, legs, age
log= {}
log= {
    'name': 'fluffy',
    'color': 'dark brown',
    'legs': 6,
    'age': 5,
}
#first_name, last_name, gender, age, marital status, skills, country, city and address
student= {
    'first_name': 'sallu',
    'last_name': 'kallu',
    'gender': 'male',
    'marital status': 'unmarried',
    'skills': ['java', 'sql', 'python', 'docker', 'accounting'],
    'country': 'pak',
    'city': 'city of lights',
    'address': 'abc street karka'
}
print(len(student))
valu= student.values()
print(type(valu))
# Out:
# 8
# <class 'dict_values'>

# %%
#conditionalss means if
a=3
if a<3:
  print('Value of a is greater ')
else:
  print('lower')
# Out:
# lower

# %%
a= int(input())
if a<=5 and a>=5:
  print('not eligible')
elif a<=9:
  print('good job but not eligible')
else:
  print('eligible')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6611/2879661122.py in <cell line: 0>()
# ----> 1 a= int(input())
#       2 if a<=5 and a>=5:
#       3   print('not eligible')
#       4 elif a<=9:
#       5   print('good job but not eligible')
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
#comparing ages
print('enter your age')
your_age= int(input())
print('enter my age')
my_age= int(input())
if your_age> my_age:
  print('you are older than me')
elif your_age<my_age:
  print('i am older than you ')
else:
  print('our age is same')
# Out:
# enter your age
# 12
# enter my age
# 11
# you are older than me
